# %% [markdown]
# # Certificados de cognitive Class posteados como certificados estuantiles en el el linkedIn.
#
# Primero el de data Science for python:
# ![ogomezspythonfordatascience.png](data:image/png;base64,...)

# %% [markdown]
# Ahora el de data visualization with python:
# ![ogomezsdataanalysiswithpython.png](data:image/png;base64,...)

# %% [markdown]
# Y por ultimo el pantallazo de postear el curso data analysis with python:
# ![ogomezsdataanalysiswithpython.png](data:image/png;base64,...)
