# %% [markdown]
# ###Oscar Alejandro Gómez Suarez
#
#
# #### Codigo recuperado de
# https://www.smashingmagazine.com/2009/08/designing-a-html-5-layout-from-scratch/

# %% [markdown]
# Link a la pagina:
#
# http://ogomezs.pythonanywhere.com/
