# %% [markdown]
# ## Certificado Data Structures
# ### Oscar Alejandro Gómez Suarez

# %% [markdown]
# ### Link  a la publicación en Coursera
#
# https://coursera.org/share/2a68a1b5d40c9abcdea869233b66e3b3

# %% [markdown]
# ### Pantallazo de prueba
#
# ![image.png](data:image/png;base64,...)
