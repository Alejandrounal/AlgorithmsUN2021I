# %% [markdown]
# ##Week 1. Algorithmic ToolBox
# ##Exercises of Algorithm Toolbox / Coursera
#
# ### Oscar Alejandro Gómez Suarez
#
# ### Grupo 4

# %% [markdown]
# ###Suma de Dos digitos en c++

# %%
# %%writefile sum.cpp
# #include <iostream>
#
# int sum_of_two_digits(int first_digit, int second_digit) {
#     return first_digit + second_digit;
# }
#
# int main() {
#     int a = 0;
#     int b = 0;
#     std::cin >> a;
#     std::cin >> b;
#     std::cout << sum_of_two_digits(a, b);
#     return 0;
# }
# Out:
# Writing sum.cpp

# %%
# Se utilizan los comandos de linux

# !g++ sum.cpp -o sum
# !./sum
# Out:
# 10 20
# 30

# %% [markdown]
# ##Archivos de prueba

# %%
# %%writefile input1.txt
# 4 8
# Out:
# Writing input1.txt

# %%
# %%writefile output1.txt
# 12
# Out:
# Writing output1.txt

# %%
# %%writefile input2.txt
# -5 9
# Out:
# Writing input2.txt

# %%
# %%writefile output2.txt
# 4
# Out:
# Writing output2.txt

# %%
# Nuevamente comandos de linux '< ' para pasarle como parametro al archivo compilado sum
# !./sum < input1.txt
# Out:
# 12

# %%
# !./sum < input2.txt
# Out:
# 4

# %% [markdown]
# ### Suma de dos digitos en python

# %%
# %%writefile sum.py
# python3

def sum_of_two_digits(first_digit, second_digit):
    return first_digit + second_digit

if __name__ == '__main__':
    a, b = map(int, input().split())
    print(sum_of_two_digits(a, b))
# Out:
# Writing sum.py

# %%
# !python sum.py
# Out:
# 5 6
# 11

# %% [markdown]
# ###Maximum Pairwise Product Programming en c++

# %%
# Naive aproximation
# %%writefile max_pairwise_product1.cpp
#include <iostream>
#include <vector>
#include <algorithm>

int MaxPairwiseProduct(const std::vector<int>& numbers) {
    int max_product = 0;
    int n = numbers.size();

    for (int first = 0; first < n; ++first) {
        for (int second = first + 1; second < n; ++second) {
            max_product = std::max(max_product,
                numbers[first] * numbers[second]);
        }
    }

    return max_product;
}

int main() {
    int n;
    std::cin >> n;
    std::vector<int> numbers(n);
    for (int i = 0; i < n; ++i) {
        std::cin >> numbers[i];
    }

    std::cout << MaxPairwiseProduct(numbers) << "\n";
    return 0;
}
# Out:
# Writing max_pairwise_product1.cpp

# %%
# !g++ max_pairwise_product1.cpp -o max_pairwise_product1
# !./max_pairwise_product1
# Out:
# 6
# 10 2 6 30 6 50
# 1500

# %% [markdown]
# #### Casos límites (causar un overflow)

# %%
# %%writefile input1.txt
# 6
# 1 3 200000 9 200000 23
# Out:
# Overwriting input1.txt

# %%
# %time
# !./max_pairwise_product1 < input1.txt
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.11 µs
# 1345294336

# %%
# Utilizando Long
# %%writefile max_pairwise_product2.cpp
#include <iostream>
#include <vector>
#include <algorithm>

long long MaxPairwiseProduct(const std::vector<int>& numbers) {
    long long max_product = 0LL;
	  long long aux_product = 0LL;
    int n = numbers.size();

    for (int first = 0; first < n; ++first) {
        for (int second = first + 1; second < n; ++second) {
			       aux_product =  (long long) numbers[first] * numbers[second];
            if ( max_product < aux_product)  {
				        max_product = aux_product;
             }
        }
    }

    return max_product;
}

int main() {
    int n;
    std::cin >> n;
    std::vector<int> numbers(n);
    for (int i = 0; i < n; ++i) {
        std::cin >> numbers[i];
    }

    std::cout << MaxPairwiseProduct(numbers) << "\n";
    return 0;
}
# Out:
# Writing max_pairwise_product2.cpp

# %%
# %time
# !g++ max_pairwise_product2.cpp -o max_pairwise_product2
# !./max_pairwise_product2 < input1.txt
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.25 µs
# 40000000000

# %%
# Algoritmo eficiente
# %%writefile max_pairwise_product_3.cpp
#include <iostream>
#include <vector>
#include <algorithm>

int main() {
    int n;
    std::cin >> n;
    long long max = 0LL;
    long long max2 = 0LL;
    long long number = 0LL ;
    for (int i = 0; i < n; ++i) {
        std::cin >> number;
        if(number >= max){
            max2 = max;
            max = number;
        }
        else if(number > max2 ){
            max2 = number;
        }
    }
    std::cout << max*max2 << "\n";

    return 0;
}
# Out:
# Writing max_pairwise_product_3.cpp

# %%
# !g++ max_pairwise_product_3.cpp -o max_pairwise_product_3
# !./max_pairwise_product_3
# Out:
# 3
# 10
# 2
# 5
# 50

# %%
# Generar el archivo de entrada

import numpy as np
from random import randint

def generate_numbers(min_n, max_n, min_ai, max_ai):
  n = randint(min_n, max_n)
  print("Writing {} numbers in stress.txt (...)".format(n))
  f = open("stress.txt", 'w')
  f.write("{}\n".format(n))

  for i in range(n):
    ai = randint(min_ai, max_ai)
    f.write("{}".format(ai)+" ")
  
  print("Operation completed")

# %%
# %%time
# max_boundary = (2*10)**5
max_boundary = (2*10)**5
generate_numbers(2,max_boundary, 0, max_boundary)
# Out:
# Writing 983253 numbers in stress.txt (...)
# Operation completed
# CPU times: user 1.84 s, sys: 23.5 ms, total: 1.86 s
# Wall time: 1.87 s

# %%
## Read first 100 bytes of stress.txt
# !head -c 100 stress.txt
# Out:
# 983253
# 285270 2103346 1988848 376506 2844848 1343170 94876 2895238 2183610 435809 877486 697314 2918

# %%
# %%time
#Using naive
# !./max_pairwise_product2 < stress.txt
# Out:
# ^C
# CPU times: user 4.4 s, sys: 480 ms, total: 4.88 s
# Wall time: 13min 13s

# %%
# Algorimo naive en python
# %%writefile max_pairwise_product_naive.py

def max_pairwise_product(numbers):
    n = len(numbers)
    max_product = 0
    for first in range(n):
        for second in range(first + 1, n):
            max_product = max(max_product,
                numbers[first] * numbers[second])

    return max_product


if __name__ == '__main__':
    input_n = int(input())
    input_numbers = [int(x) for x in input().split()]
    print(max_pairwise_product(input_numbers))
# Out:
# Writing max_pairwise_product_naive.py

# %%
# !python3 max_pairwise_product_naive.py
# Out:
# 5
# 10 6 8 20 3
# 200

# %%
# Algoritmo en python eficiente
# %%writefile max_pairwise_product_efficent.py
#python3
def max_pairwise_product_efficent():
  n = int(input())
  numbers = [int(x) for x in input().split()]
  max = 0
  max2 = 0

  for i in range(len(numbers)):
    if(numbers[i]>= max):
      max2 = max
      max  = numbers[i]
    elif(numbers[i] > max2):  
      max2 = numbers[i]

  return (max*max2)

print(max_pairwise_product_efficent())
# Out:
# Overwriting max_pairwise_product_efficent.py

# %%
# !python3 max_pairwise_product_efficent.py
# Out:
# 5
# 10 6 8 20 3
# 200

# %%
# Usando el stress testing 
# Naive Algorithm
# %%time
# !python3 max_pairwise_product_naive.py < stress.txt
# Out:
# Traceback (most recent call last):
#   File "max_pairwise_product_naive.py", line 16, in <module>
#     print(max_pairwise_product(input_numbers))
#   File "max_pairwise_product_naive.py", line 8, in max_pairwise_product
#     numbers[first] * numbers[second])
# KeyboardInterrupt
# CPU times: user 2.34 s, sys: 292 ms, total: 2.63 s
# Wall time: 7min 12s

# %%
# Utlizando el algortimo efienciente 
# %%time
# !python3 max_pairwise_product_efficent.py < stress.txt
# Out:
# 10239977600000
# CPU times: user 8.27 ms, sys: 7.4 ms, total: 15.7 ms
# Wall time: 617 ms
