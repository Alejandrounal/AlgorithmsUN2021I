# %% [markdown]
# ## Certificado Algorithic Toolbox
# ### Oscar Alejandro Gómez Suarez

# %% [markdown]
# ###Link a la publicación en linkedIn
#
# https://www.linkedin.com/posts/oscar-alejandro-g%C3%B3mez-suarez-bbb39088_completion-certificate-for-algorithmic-toolbox-activity-6744014666592342016-U_II

# %% [markdown]
# ### Pantallazo de la publicación
# ![image.png](data:image/png;base64,...)
